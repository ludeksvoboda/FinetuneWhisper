# %%
import IPython.display
from pathlib import Path

import os
import numpy as np

import torch
from torch import nn
import pandas as pd
import whisper
import torchaudio
import torchaudio.transforms as at

from pytorch_lightning import LightningModule
from pytorch_lightning import Trainer, seed_everything
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger

from tqdm.notebook import tqdm
import evaluate

from transformers import (
    AdamW,
    get_linear_schedule_with_warmup
)

# %%
import gdown
gdown.download('https://drive.google.com/u/0/uc?id=19oAw8wWn3Y7z6CKChRdAyGOB9yupL_Xt', 'jvs.zip', quiet=False)
# !unzip jvs.zip -d ./jvs

# %%
DATASET_DIR = "jvs/jvs_ver1"
SAMPLE_RATE = 16000
BATCH_SIZE = 2
TRAIN_RATE = 0.8

AUDIO_MAX_LENGTH = 480000
TEXT_MAX_LENGTH = 120
SEED = 3407
DEVICE = "gpu" if torch.cuda.is_available() else "cpu"
seed_everything(SEED, workers=True)
# Out:
# Global seed set to 3407
# 3407

# %%
def load_wave(wave_path, sample_rate:int=16000) -> torch.Tensor:
    waveform, sr = torchaudio.load(wave_path, normalize=True)
    if sample_rate != sr:
        waveform = at.Resample(sr, sample_rate)(waveform)
    return waveform

# %%
dataset_dir = Path(DATASET_DIR)
transcripts_path_list = list(dataset_dir.glob("*/*/transcripts_utf8.txt"))
print(len(transcripts_path_list))
# Out:
# 400

# %%
def get_audio_file_list(transcripts_path_list, text_max_length=120, audio_max_sample_length=480000, sample_rate=16000):
    audio_transcript_pair_list = []
    for transcripts_path in tqdm(transcripts_path_list):
        # audioファイルのディレクトリ確認
        audio_dir = transcripts_path.parent / "wav24kHz16bit"
        if not audio_dir.exists():
            print(f"{audio_dir}は存在しません。")
            continue

        # 翻訳テキストからAudioIdとテキストを取得
        with open(transcripts_path, "r") as f:
            text_list = f.readlines()
        for text in text_list:
            audio_id, text = text.replace("\n", "").split(":")
            #print(audio_id, text)

            audio_path = audio_dir / f"{audio_id}.wav"
            if audio_path.exists():
                # データのチェック
                audio = load_wave(audio_path, sample_rate=sample_rate)[0]
                if len(text) > text_max_length or len(audio) > audio_max_sample_length:
                    print(len(text), len(audio))
                    continue
                audio_transcript_pair_list.append((audio_id, str(audio_path), text))
    return audio_transcript_pair_list

train_num = int(len(transcripts_path_list) * TRAIN_RATE)
train_transcripts_path_list, eval_transcripts_path_list = transcripts_path_list[:train_num], transcripts_path_list[train_num:]
train_audio_transcript_pair_list = get_audio_file_list(train_transcripts_path_list, TEXT_MAX_LENGTH, AUDIO_MAX_LENGTH, SAMPLE_RATE)
eval_audio_transcript_pair_list = get_audio_file_list(eval_transcripts_path_list, TEXT_MAX_LENGTH, AUDIO_MAX_LENGTH, SAMPLE_RATE)
print("TRAIN AUDIO DATASET NUM: ", len(train_audio_transcript_pair_list))
print("EVAL AUDIO DATASET NUM: ", len(eval_audio_transcript_pair_list))
# Out:
#   0%|          | 0/320 [00:00<?, ?it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]
# TRAIN AUDIO DATASET NUM:  11982
# EVAL AUDIO DATASET NUM:  3000

# %%
train_audio_transcript_pair_list
# Out:
# [('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('BASIC5000_0923',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/BASIC5000_0923.wav',
#   'ここから、ディズニーランド行きのバスに乗れると思います。'),
#  ('BASIC5000_0090',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/BASIC5000_0090.wav',
#   'ガリレオは、二つの鉄の玉を、塔のてっぺんから落とした。'),
#  ('UT-PARAPHRASE-sent171-phrase1',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/UT-PARAPHRASE-sent171-phrase1.wav',
#   '預金の預け入れのほか、通帳の記帳もできるようにする。'),
#  ('BASIC5000_2383',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/BASIC5000_2383.wav',
#   'エミリー以上にすばらしいアップルパイを焼く人はいない。'),
#  ('UT-PARAPHRASE-sent067-phrase2',
#   'jvs/jvs_ver1/jvs094/whisper10/wav24kHz16bit/UT-PARAPHRASE-sent067-phrase2.wav',
#   '革新の立場で、今の自民党の悪政を変えていく勢力を,集めることを目指す。'),
#  ('BASIC5000_0923',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0923.wav',
#   'ここから、ディズニーランド行きのバスに乗れると思います。'),
#  ('BASIC5000_0090',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0090.wav',
#   'ガリレオは、二つの鉄の玉を、塔のてっぺんから落とした。'),
#  ('UT-PARAPHRASE-sent171-phrase1',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent171-phrase1.wav',
#   '預金の預け入れのほか、通帳の記帳もできるようにする。'),
#  ('BASIC5000_2383',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_2383.wav',
#   'エミリー以上にすばらしいアップルパイを焼く人はいない。'),
#  ('UT-PARAPHRASE-sent067-phrase2',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent067-phrase2.wav',
#   '革新の立場で、今の自民党の悪政を変えていく勢力を,集めることを目指す。'),
#  ('LOANWORD128_112',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/LOANWORD128_112.wav',
#   'ヴュルツブルク中央駅は、ドイツにある駅である。'),
#  ('ONOMATOPEE300_003',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/ONOMATOPEE300_003.wav',
#   '初めて彼とあった時、その何気ない仕草に私はめろめろになってしまったんだと告白した'),
#  ('LOANWORD128_026',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/LOANWORD128_026.wav',
#   '少し前の女の子はみんな携帯電話をデコっていた。'),
#  ('ONOMATOPEE300_287',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/ONOMATOPEE300_287.wav',
#   '漬物石をどすんと置いて、しばらく時間がたてば、漬物の完成だ。'),
#  ('BASIC5000_1851',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_1851.wav',
#   'タランチュラは、そのいけにえを、素早く捕まえた。'),
#  ('BASIC5000_0145',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0145.wav',
#   '５マイルは、ピクニックに適した距離だ。'),
#  ('TRAVEL1000_0019',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/TRAVEL1000_0019.wav',
#   'バッグを、頭上の荷物棚に入れてください。'),
#  ('BASIC5000_1179',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_1179.wav',
#   '吉雄は私がその箱を持ち上げるのを手伝ってくれた。'),
#  ('TRAVEL1000_0277',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/TRAVEL1000_0277.wav',
#   'ニューヨークではどこに宿泊しますか。'),
#  ('BASIC5000_2099',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_2099.wav',
#   '様子から判断すれば、彼は兵士かもしれない。'),
#  ('UT-PARAPHRASE-sent048-phrase1',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent048-phrase1.wav',
#   'コートのすそに取り付けたタグを、エラーなく読み取れるかなどが、焦点となる。'),
#  ('BASIC5000_1841',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_1841.wav',
#   'タバコをへらすことより、むしろ、タバコをやめるってのはどうですか。'),
#  ('BASIC5000_0076',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0076.wav',
#   '被写体に気づかれないようにそぉっとカメラを取り出し、ファインダーを覗く。'),
#  ('TRAVEL1000_0690',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/TRAVEL1000_0690.wav',
#   'そちらへは、どのように行けばよいでしょうか。'),
#  ('TRAVEL1000_0338',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/TRAVEL1000_0338.wav',
#   'トラベラーズチェック、クレジットカード、現金とパスポートです。'),
#  ('BASIC5000_2876',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_2876.wav',
#   'クリスマスにお会い出来るのを楽しみにしています。'),
#  ('BASIC5000_0443',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0443.wav',
#   'また近いうちにお目にかかりましょう。'),
#  ('BASIC5000_0061',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0061.wav',
#   'ミルトンの作品を読んだことがありますか。'),
#  ('UT-PARAPHRASE-sent061-phrase2',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent061-phrase2.wav',
#   'だが、パトロンに、廓に行こうと手紙でせがむ。'),
#  ('ONOMATOPEE300_156',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/ONOMATOPEE300_156.wav',
#   '台風が来ていたので、家の外では風がごーごーと吹き荒れていて、とても表に出られなかった。'),
#  ('BASIC5000_1919',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_1919.wav',
#   '放送される英語の番組を聞くことがありますか。'),
#  ('BASIC5000_0010',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0010.wav',
#   '末期試験に備えて、本当に気合いを入れて勉強しなきゃ。'),
#  ('BASIC5000_2602',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_2602.wav',
#   '市長の家族は、一日中脅迫電話に悩まされた。'),
#  ('BASIC5000_1490',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_1490.wav',
#   '顧みられぬ無数の漂流者が、家を求めてる。'),
#  ('BASIC5000_0978',
#   'jvs/jvs_ver1/jvs094/nonpara30/wav24kHz16bit/BASIC5000_0978.wav',
#   'お顔が見えるように、もっと近くにおいでください。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('VOICEACTRESS100_006',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_006.wav',
#   'ツュレンハルト領は、ヴュルテンベルク領に編入された。'),
#  ('VOICEACTRESS100_007',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_007.wav',
#   '時間領域と、空間領域で共通する処理手法は、フィルタリングによる、入力信号の強化である。'),
#  ('VOICEACTRESS100_008',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_008.wav',
#   'シャンチーの専業プロは、チームから支払われる給料と、対局費を、主な収入としている。'),
#  ('VOICEACTRESS100_009',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_009.wav',
#   'また禰寝氏は、中山王の治める、琉球王国との交易にも参加した。'),
#  ('VOICEACTRESS100_010',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_010.wav',
#   'スマートフォンから、フィーチャーフォンまで、マルチデバイスに対応。'),
#  ('VOICEACTRESS100_011',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_011.wav',
#   '軽妙洒脱なナレーションから、情緒感溢れる語りまで、幅広い表現力を持つ。'),
#  ('VOICEACTRESS100_012',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_012.wav',
#   '構造は、鋼製の単一アーチで、橋脚は、石積みである。'),
#  ('VOICEACTRESS100_013',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_013.wav',
#   'そこへ、オーナーが新しいシェフとして、腕利きのヒョヌクを招く。'),
#  ('VOICEACTRESS100_014',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_014.wav',
#   'クィーンズアベニューアルファに所属している。'),
#  ('VOICEACTRESS100_015',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_015.wav',
#   '一方で、漁業と商業で、リャネス港は繁栄していた。'),
#  ('VOICEACTRESS100_016',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_016.wav',
#   'この、ニューサウスウェールズ代表チームが、ワラビーズの中核となって行く。'),
#  ('VOICEACTRESS100_017',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_017.wav',
#   'ただし、ギャンブル依存症の入院治療を行っている病院は、わずかである。'),
#  ('VOICEACTRESS100_018',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_018.wav',
#   '他のメジャーなディストリビューションに比べ、セキュリティー上の問題の修正が、遅い場合もある。'),
#  ('VOICEACTRESS100_019',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_019.wav',
#   'ベルガートーア前の、ヴェディゲンウーファーパークには、戦争と弾圧の犠牲者のための記念碑が建っている。'),
#  ('VOICEACTRESS100_020',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_020.wav',
#   '全米パブリッシャーズ協会の、ベストストラテジーゲームオブザイヤーを、日本人として受賞。'),
#  ('VOICEACTRESS100_021',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_021.wav',
#   '痛みは、点滴より鎮痛薬を、静脈投与することで、鎮痛を行う。'),
#  ('VOICEACTRESS100_022',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_022.wav',
#   'このときに、浮遊大陸プルヴァマにある、中立国、ビュエルバが、ある情報筋から、バッシュ将軍の処刑と、前王女、アーシェの自害を発表。'),
#  ('VOICEACTRESS100_023',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_023.wav',
#   '南西部ウォーレンは、ベイアーマンファームズと、フィッツジェラルドの地区で、構成される。'),
#  ('VOICEACTRESS100_024',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_024.wav',
#   'このため、プラズマ中のイオンや、電子の持つ、平均運動エネルギーを、温度で表現することがある。'),
#  ('VOICEACTRESS100_025',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_025.wav',
#   'その飄々とした人柄が、老若男女に慕われている。'),
#  ('VOICEACTRESS100_026',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_026.wav',
#   '現在、ニュージャージー州、ムーアズタウンに住んでいる。'),
#  ('VOICEACTRESS100_027',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_027.wav',
#   '町域にあった、三根山藩は、長岡藩に、米百俵を送ったことで有名。'),
#  ('VOICEACTRESS100_028',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_028.wav',
#   'このとき、ペリメーデーは、アムピクトリュオーンに同行して、テーバイに来ていた、リキュムニオスに、妻としてあたえられた。'),
#  ('VOICEACTRESS100_029',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_029.wav',
#   '現在の滑走を目的とした、スキーブーツは、硬いプラスチックシェルと、柔らかいインナーブーツからなる。'),
#  ('VOICEACTRESS100_030',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_030.wav',
#   '防氷ブーツは、表面に張られた、ゴム製の薄い膜でできている。'),
#  ('VOICEACTRESS100_031',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_031.wav',
#   '後者の代表が、ウェッジウッドの、ジャスパーウェアである。'),
#  ('VOICEACTRESS100_032',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_032.wav',
#   'キー局が発信する、ニュースネットワーク名を冠したタイトルの、ニュース番組の中では、レギュラー放送が、最も多い。'),
#  ('VOICEACTRESS100_033',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_033.wav',
#   '芸能プロダクション、アミューズのグループ企業。'),
#  ('VOICEACTRESS100_034',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_034.wav',
#   '長母音を省略して、エリュシオンとも表記される。'),
#  ('VOICEACTRESS100_035',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_035.wav',
#   '森永のおいしい牛乳は、濃い青色に、牛乳瓶をあしらったデザインの、パック牛乳である。'),
#  ('VOICEACTRESS100_036',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_036.wav',
#   '番組冒頭を、東京ムービー製作のアニメーションで、表現する点も、共通していた。'),
#  ('VOICEACTRESS100_037',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_037.wav',
#   'コミューンは、セーヌ川と、エソンヌ川の、合流地点となっている。'),
#  ('VOICEACTRESS100_038',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_038.wav',
#   '同時に、福井ミラクルエレファンツに、コーチ兼任で、入団することが発表された。'),
#  ('VOICEACTRESS100_039',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_039.wav',
#   '夫である小室が、救急車を呼び、都内病院に、緊急搬送される。'),
#  ('VOICEACTRESS100_040',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_040.wav',
#   'ギレスピーは、マッギーを通じて、イネスと知り合った。'),
#  ('VOICEACTRESS100_041',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_041.wav',
#   'フォンテーヌブロー様式では、寓意的な絵が、漆喰のモールドに使われている。'),
#  ('VOICEACTRESS100_042',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_042.wav',
#   '祭神は、ヴィシュヌ派の聖人、スワーミーナーラーヤン。'),
#  ('VOICEACTRESS100_043',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_043.wav',
#   'ハーデースが、ペルセポネーに恋をしたのは、アプロディーテーの、策略であるとされている。'),
#  ('VOICEACTRESS100_044',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_044.wav',
#   'クウェーンバーンチャーンは、小さなコミュニティーで、農業や、商業を中心に、成り立っていたと、考えられている。'),
#  ('VOICEACTRESS100_045',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_045.wav',
#   'ヴェーザー自転車道や、ミューレンルートに従った、サイクリングツアーは、ペータースハーゲンを、経由する。'),
#  ('VOICEACTRESS100_046',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_046.wav',
#   'フォーミュラカーは、通常、オープンホイールで、シングルシーターである。'),
#  ('VOICEACTRESS100_047',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_047.wav',
#   '同日朝に、大阪難波で、出発セレモニーが開催され、営業運転に、充当された。'),
#  ('VOICEACTRESS100_048',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_048.wav',
#   'そして、インデペンデント紙の、読者投票で選ぶ、プレミアリーグ最優秀ゴールキーパーに選ばれた。'),
#  ('VOICEACTRESS100_049',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_049.wav',
#   'プレイヤーキャラクターは、宮殿を占拠した、邪悪なクリーチャーに遭遇する。'),
#  ('VOICEACTRESS100_050',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_050.wav',
#   'フィールドマーケティングは、歴史的には、一方通行のコミュニケーションツールとして、考えられてきた。'),
#  ('VOICEACTRESS100_051',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_051.wav',
#   'デビュー後の数年間は、ベビーフェイスとして、本名で活動。'),
#  ('VOICEACTRESS100_052',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_052.wav',
#   '学校や病院などの、給食業務で、栄養素を計算する上で、重要な資料のひとつである。'),
#  ('VOICEACTRESS100_053',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_053.wav',
#   '当時、あやしいワールドに常駐していた擬古猫が、空白にて発表。'),
#  ('VOICEACTRESS100_054',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_054.wav',
#   '裕福なニューヨーカー達は、グレーヴセンド、競馬場や、シープシェッドベイ、競馬場などに集い、海沿いの高級レストランや、ホテルを利用した。'),
#  ('VOICEACTRESS100_055',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_055.wav',
#   'ウォリアーズミックスマーシャルアーツアカデミー所属。'),
#  ('VOICEACTRESS100_056',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_056.wav',
#   'ところが、エリュシクトーンは、ニュムペーの制止も聞かずに、デーメーテールの樫を、切り倒した。'),
#  ('VOICEACTRESS100_057',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_057.wav',
#   'このジェシー役でステイモスは、エミー賞にノミネートされたこともある。'),
#  ('VOICEACTRESS100_058',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_058.wav',
#   'スウェーデン移民の両親の許に、マサチューセッツ州、ケンブリッジにて生まれる。'),
#  ('VOICEACTRESS100_059',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_059.wav',
#   '球宴のファン投票でも、人気が偶像化していた、長嶋茂雄に肉薄する。'),
#  ('VOICEACTRESS100_060',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_060.wav',
#   '母は、ピーターマリッツバーグの精神病院に入院しているときに、ベッシーを産む。'),
#  ('VOICEACTRESS100_061',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_061.wav',
#   'ポイントガードから、スモールフォワードまでこなせる、総合力が高いユーティリティープレーヤーである。'),
#  ('VOICEACTRESS100_062',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_062.wav',
#   'グレッグは、ミシシッピ州、アバディーンにある、オッドフェローズ墓地に埋葬されることになった。'),
#  ('VOICEACTRESS100_063',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_063.wav',
#   '大当り終了後は、グラディエーターチャンスに突入する。'),
#  ('VOICEACTRESS100_064',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_064.wav',
#   'この菌による病気は、灰色かび病と名づけられているものが多い。'),
#  ('VOICEACTRESS100_065',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_065.wav',
#   'レギュラーメンバーの顔写真をクリックした後に、ムービープレイヤー風に再生されるという、特異な形式となっている。'),
#  ('VOICEACTRESS100_066',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_066.wav',
#   '肝臓への酸素供給は、肝動脈と、低圧系の門脈を介して、行われている。'),
#  ('VOICEACTRESS100_067',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_067.wav',
#   'デッドキーは、タイプライターや、コンピュータのキーボードにおける、特殊な装飾キーである。'),
#  ('VOICEACTRESS100_068',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_068.wav',
#   'シャンシャン馬は、鵜戸神宮へ参拝する、新婚夫婦が乗っていた馬のこと。'),
#  ('VOICEACTRESS100_069',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_069.wav',
#   'ブルーリッジ山脈の源流から、リッチモンドまで、多くの早瀬や淵が、釣りや急流くだりを楽しませてくれる。'),
#  ('VOICEACTRESS100_070',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_070.wav',
#   'ボーハンは、イーストマンら、ギャングのスピークイージーの上がりから、賄賂を取っていたとも噂された。'),
#  ('VOICEACTRESS100_071',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_071.wav',
#   'ペンシルベニア州、フィラデルフィアの郊外、ウィンレッドのレンキナウ病院で生まれた。'),
#  ('VOICEACTRESS100_072',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_072.wav',
#   'ブラッグは、ビューエル軍よりも、劣勢だったために、この機会を生かすことを躊躇した。'),
#  ('VOICEACTRESS100_073',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_073.wav',
#   '上院議員として、バーンウェルは、カリフォルニア州の、連邦加入に賛成した。'),
#  ('VOICEACTRESS100_074',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_074.wav',
#   'レジェンドシリーズをベースに、ヨーフリー機構を備えた、ビューカメラ。'),
#  ('VOICEACTRESS100_075',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_075.wav',
#   '楽曲のセンターポジションは、エーケービーフォーティーエイトの、高橋みなみが務めた。'),
#  ('VOICEACTRESS100_076',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_076.wav',
#   'ディオニューソスの、寵愛を受ける、オイネウス王と、妃、アルタイアーの間に、カリュドーンの王女として、生を受けた。'),
#  ('VOICEACTRESS100_077',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_077.wav',
#   '大西洋上の、巡航高度から、動力なしで、地上へ滑空飛行し、緊急着陸に成功した。'),
#  ('VOICEACTRESS100_078',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_078.wav',
#   '表現行列の指標表を、分子の対称性を表す、点群の指標表を用いて、既約表現へ分解する。'),
#  ('VOICEACTRESS100_079',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_079.wav',
#   '大洋漁業オーナーの、中部謙吉の命を受けて、プロ野球球団の、大洋ホエールズに関わる。'),
#  ('VOICEACTRESS100_080',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_080.wav',
#   'かすかに聞こえてくる1931年版の讃美歌が、次第に大きくなっていく。'),
#  ('VOICEACTRESS100_081',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_081.wav',
#   'モーイーデーン岩壁地域の上部は、プラーサートプラウィハーン寺院遺跡へ繋がる、タイ側参道に続いている。'),
#  ('VOICEACTRESS100_082',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_082.wav',
#   'カーミラ星と呼ばれている惑星から、宇宙船に乗って、地球に侵入した宇宙人。'),
#  ('VOICEACTRESS100_083',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_083.wav',
#   'ドッガーバンクは、タラやニシンの漁獲量が多い、重要な、漁場である。'),
#  ('VOICEACTRESS100_084',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_084.wav',
#   '少年時代は、ロシア帝国、チェルニーヒウ県、プルィルークィ郡、トロスチャヌィーツャ村で過ごした。'),
#  ('VOICEACTRESS100_085',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_085.wav',
#   '遺灰のほとんどは、スウェーデン西海岸の、ブーヒュースレーン地方の小島にある漁村、フヤルバッカ周辺の海に、散骨された。'),
#  ('VOICEACTRESS100_086',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_086.wav',
#   '国境を越えて、列車は、改良された在来線に沿って、アーヘン中央駅に向かう。'),
#  ('VOICEACTRESS100_087',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_087.wav',
#   '福岡ダイエーホークスではなく、長距離砲の補強を目指していた、大阪近鉄バファローズから、オファーを受けて入団。'),
#  ('VOICEACTRESS100_088',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_088.wav',
#   'そこには、百ドル札と、アメリカに来いという、短いメッセージだけだった。'),
#  ('VOICEACTRESS100_089',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_089.wav',
#   '現在は、バッハをモチーフとした、ハープシコードの作曲家として、記憶されている。'),
#  ('VOICEACTRESS100_090',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_090.wav',
#   '戦闘服は、両腕を露出し、両脚が、アンダースーツで覆われている。'),
#  ('VOICEACTRESS100_091',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_091.wav',
#   '同母姉に、スウェーデン王妃、ジョゼフィーヌがいる。'),
#  ('VOICEACTRESS100_092',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_092.wav',
#   '紫外線は、表面エネルギーの、小さいポリマーを接着する際の、前処理に利用される。'),
#  ('VOICEACTRESS100_093',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_093.wav',
#   '自身のページで、メッセージや、公開コメントを通して、レビューを投稿したユーザーと、コミュニケーションを取ることが可能である。'),
#  ('VOICEACTRESS100_094',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_094.wav',
#   '若き日の反逆ゆえに、宇宙の中央を追放されて、惑星、地球にやってきた主人公、ベルゼバブが、宇宙船カルナークのなかで、孫に語る壮大な物語。'),
#  ('VOICEACTRESS100_095',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_095.wav',
#   'ジャガーとは対照的に、ボディービルダーを髣髴とさせる、マッチョな体育会系の外見が特徴。'),
#  ('VOICEACTRESS100_096',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_096.wav',
#   'ペンシルベニア州、ピッツバーグの、アレゲーニー高校を卒業し、カリフォルニア大学、バークレー校に入学。'),
#  ('VOICEACTRESS100_097',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_097.wav',
#   'この概念の導入によって、様々なバリエーションの、流体のコンピューターシミュレーションが、高い精度で可能となった。'),
#  ('VOICEACTRESS100_098',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_098.wav',
#   '乾ドックに入渠して、オーバーホールすべきかどうか、パフォーマンスがチェックされた。'),
#  ('VOICEACTRESS100_099',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_099.wav',
#   'デビューウェイトは、スーパーバンタム級ではなく、フェザー級だった。'),
#  ('VOICEACTRESS100_100',
#   'jvs/jvs_ver1/jvs094/parallel100/wav24kHz16bit/VOICEACTRESS100_100.wav',
#   'アーリーは、降雨の中を、南のバージニア州、ウィンチェスター近くの、フィッシャーズヒルまで、軍を退いた。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('LOANWORD128_112',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/LOANWORD128_112.wav',
#   'ヴュルツブルク中央駅は、ドイツにある駅である。'),
#  ('ONOMATOPEE300_003',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/ONOMATOPEE300_003.wav',
#   '初めて彼とあった時、その何気ない仕草に私はめろめろになってしまったんだと告白した'),
#  ('LOANWORD128_026',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/LOANWORD128_026.wav',
#   '少し前の女の子はみんな携帯電話をデコっていた。'),
#  ('ONOMATOPEE300_287',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/ONOMATOPEE300_287.wav',
#   '漬物石をどすんと置いて、しばらく時間がたてば、漬物の完成だ。'),
#  ('BASIC5000_1851',
#   'jvs/jvs_ver1/jvs094/falset10/wav24kHz16bit/BASIC5000_1851.wav',
#   'タランチュラは、そのいけにえを、素早く捕まえた。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('BASIC5000_1378',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/BASIC5000_1378.wav',
#   '一郎はどことなく傷ついたように言ったが、それが嘘っぱちであることは、こいつとの長年の付き合いが教えてくれた。'),
#  ('TRAVEL1000_0418',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/TRAVEL1000_0418.wav',
#   '出発の、少なくとも30分前に、搭乗手続きをしてください。'),
#  ('TRAVEL1000_0117',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/TRAVEL1000_0117.wav',
#   'それはトイレつきで、食事込みです。'),
#  ('BASIC5000_0225',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/BASIC5000_0225.wav',
#   '面前で人を誉めるような人を信用するな。'),
#  ('UT-PARAPHRASE-sent016-phrase1',
#   'jvs/jvs_ver1/jvs024/whisper10/wav24kHz16bit/UT-PARAPHRASE-sent016-phrase1.wav',
#   'この落差は、いったい何なのか。'),
#  ('BASIC5000_1378',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_1378.wav',
#   '一郎はどことなく傷ついたように言ったが、それが嘘っぱちであることは、こいつとの長年の付き合いが教えてくれた。'),
#  ('TRAVEL1000_0418',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0418.wav',
#   '出発の、少なくとも30分前に、搭乗手続きをしてください。'),
#  ('TRAVEL1000_0117',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0117.wav',
#   'それはトイレつきで、食事込みです。'),
#  ('BASIC5000_0225',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0225.wav',
#   '面前で人を誉めるような人を信用するな。'),
#  ('UT-PARAPHRASE-sent016-phrase1',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent016-phrase1.wav',
#   'この落差は、いったい何なのか。'),
#  ('BASIC5000_1024',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_1024.wav',
#   '昨今、個人的自由は少なくなっている。'),
#  ('BASIC5000_0193',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0193.wav',
#   'ご家族もごいっしょに連れてこられたのですか。'),
#  ('TRAVEL1000_0286',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0286.wav',
#   '飛行機はサービスがよく、可能な限り、客の要望に答えられるように努力しています。'),
#  ('TRAVEL1000_0594',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0594.wav',
#   'このセーターの色違いのがありますか。'),
#  ('BASIC5000_0394',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0394.wav',
#   'パシフィック通りに行くには、このバスでいいんでしょうか。'),
#  ('ONOMATOPEE300_050',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/ONOMATOPEE300_050.wav',
#   '今日から始まったテレビドラマは、実にほのぼのとした内容で、一日の疲れが癒されていくようです。'),
#  ('BASIC5000_1814',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_1814.wav',
#   '非、喫煙者は、新しい禁煙法を支持して結集しています。'),
#  ('BASIC5000_2909',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_2909.wav',
#   'ジャック、そんなに乱暴に振る舞うな。'),
#  ('TRAVEL1000_0745',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0745.wav',
#   '少し考えなければなりません。'),
#  ('BASIC5000_0791',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0791.wav',
#   '天候のいかんにかかわらず、駅へ迎えに参ります。'),
#  ('BASIC5000_1901',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_1901.wav',
#   '偽善とは、悪徳が、徳に対して払う、忠順の誓いである。'),
#  ('BASIC5000_0099',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0099.wav',
#   '上役に反対することは、彼も勇気のある男だ。'),
#  ('BASIC5000_1002',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_1002.wav',
#   '年輩の夫婦は贈り物より、現金を好むことが多いが、それは、そうした贈り物は必要でもなければ、置く場所もないからである。'),
#  ('BASIC5000_0156',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0156.wav',
#   '悪ふざけをすると、女の子に嫌われるよ。'),
#  ('BASIC5000_2682',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_2682.wav',
#   'チアリーダーの選抜テストを受けたいのです。'),
#  ('BASIC5000_2573',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_2573.wav',
#   '仏教の原理に従って行動するのは、難しいですか。'),
#  ('BASIC5000_1739',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_1739.wav',
#   '山を切り開いて、新しいトンネルが掘られた。'),
#  ('BASIC5000_2749',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_2749.wav',
#   '丹精をこめてつくった、この美しい織物をごらんください。'),
#  ('TRAVEL1000_0587',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0587.wav',
#   'ホテルまでの最も行きやすい道をご存じですか。'),
#  ('TRAVEL1000_0295',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0295.wav',
#   '男性用のトイレはどちらでしょうか。'),
#  ('UT-PARAPHRASE-sent058-phrase1',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent058-phrase1.wav',
#   '最近は、辞令も恐る恐る出さざるを得ない。'),
#  ('BASIC5000_3038',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_3038.wav',
#   'あらゆる毒を、風邪でも移すかのように、相手に移していく。'),
#  ('BASIC5000_2050',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_2050.wav',
#   '兄の膝は、怪我で手術が必要かもしれない。'),
#  ('BASIC5000_0853',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/BASIC5000_0853.wav',
#   '外部からの圧力が、ますます強くなってきている。'),
#  ('TRAVEL1000_0857',
#   'jvs/jvs_ver1/jvs024/nonpara30/wav24kHz16bit/TRAVEL1000_0857.wav',
#   'どうなのかなと、考えていたことがあるのですが。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('VOICEACTRESS100_006',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_006.wav',
#   'ツュレンハルト領は、ヴュルテンベルク領に編入された。'),
#  ('VOICEACTRESS100_007',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_007.wav',
#   '時間領域と、空間領域で共通する処理手法は、フィルタリングによる、入力信号の強化である。'),
#  ('VOICEACTRESS100_008',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_008.wav',
#   'シャンチーの専業プロは、チームから支払われる給料と、対局費を、主な収入としている。'),
#  ('VOICEACTRESS100_009',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_009.wav',
#   'また禰寝氏は、中山王の治める、琉球王国との交易にも参加した。'),
#  ('VOICEACTRESS100_010',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_010.wav',
#   'スマートフォンから、フィーチャーフォンまで、マルチデバイスに対応。'),
#  ('VOICEACTRESS100_011',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_011.wav',
#   '軽妙洒脱なナレーションから、情緒感溢れる語りまで、幅広い表現力を持つ。'),
#  ('VOICEACTRESS100_012',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_012.wav',
#   '構造は、鋼製の単一アーチで、橋脚は、石積みである。'),
#  ('VOICEACTRESS100_013',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_013.wav',
#   'そこへ、オーナーが新しいシェフとして、腕利きのヒョヌクを招く。'),
#  ('VOICEACTRESS100_014',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_014.wav',
#   'クィーンズアベニューアルファに所属している。'),
#  ('VOICEACTRESS100_015',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_015.wav',
#   '一方で、漁業と商業で、リャネス港は繁栄していた。'),
#  ('VOICEACTRESS100_016',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_016.wav',
#   'この、ニューサウスウェールズ代表チームが、ワラビーズの中核となって行く。'),
#  ('VOICEACTRESS100_017',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_017.wav',
#   'ただし、ギャンブル依存症の入院治療を行っている病院は、わずかである。'),
#  ('VOICEACTRESS100_018',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_018.wav',
#   '他のメジャーなディストリビューションに比べ、セキュリティー上の問題の修正が、遅い場合もある。'),
#  ('VOICEACTRESS100_019',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_019.wav',
#   'ベルガートーア前の、ヴェディゲンウーファーパークには、戦争と弾圧の犠牲者のための記念碑が建っている。'),
#  ('VOICEACTRESS100_020',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_020.wav',
#   '全米パブリッシャーズ協会の、ベストストラテジーゲームオブザイヤーを、日本人として受賞。'),
#  ('VOICEACTRESS100_021',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_021.wav',
#   '痛みは、点滴より鎮痛薬を、静脈投与することで、鎮痛を行う。'),
#  ('VOICEACTRESS100_022',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_022.wav',
#   'このときに、浮遊大陸プルヴァマにある、中立国、ビュエルバが、ある情報筋から、バッシュ将軍の処刑と、前王女、アーシェの自害を発表。'),
#  ('VOICEACTRESS100_023',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_023.wav',
#   '南西部ウォーレンは、ベイアーマンファームズと、フィッツジェラルドの地区で、構成される。'),
#  ('VOICEACTRESS100_024',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_024.wav',
#   'このため、プラズマ中のイオンや、電子の持つ、平均運動エネルギーを、温度で表現することがある。'),
#  ('VOICEACTRESS100_025',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_025.wav',
#   'その飄々とした人柄が、老若男女に慕われている。'),
#  ('VOICEACTRESS100_026',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_026.wav',
#   '現在、ニュージャージー州、ムーアズタウンに住んでいる。'),
#  ('VOICEACTRESS100_027',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_027.wav',
#   '町域にあった、三根山藩は、長岡藩に、米百俵を送ったことで有名。'),
#  ('VOICEACTRESS100_028',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_028.wav',
#   'このとき、ペリメーデーは、アムピクトリュオーンに同行して、テーバイに来ていた、リキュムニオスに、妻としてあたえられた。'),
#  ('VOICEACTRESS100_029',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_029.wav',
#   '現在の滑走を目的とした、スキーブーツは、硬いプラスチックシェルと、柔らかいインナーブーツからなる。'),
#  ('VOICEACTRESS100_030',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_030.wav',
#   '防氷ブーツは、表面に張られた、ゴム製の薄い膜でできている。'),
#  ('VOICEACTRESS100_031',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_031.wav',
#   '後者の代表が、ウェッジウッドの、ジャスパーウェアである。'),
#  ('VOICEACTRESS100_032',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_032.wav',
#   'キー局が発信する、ニュースネットワーク名を冠したタイトルの、ニュース番組の中では、レギュラー放送が、最も多い。'),
#  ('VOICEACTRESS100_033',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_033.wav',
#   '芸能プロダクション、アミューズのグループ企業。'),
#  ('VOICEACTRESS100_034',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_034.wav',
#   '長母音を省略して、エリュシオンとも表記される。'),
#  ('VOICEACTRESS100_035',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_035.wav',
#   '森永のおいしい牛乳は、濃い青色に、牛乳瓶をあしらったデザインの、パック牛乳である。'),
#  ('VOICEACTRESS100_036',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_036.wav',
#   '番組冒頭を、東京ムービー製作のアニメーションで、表現する点も、共通していた。'),
#  ('VOICEACTRESS100_037',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_037.wav',
#   'コミューンは、セーヌ川と、エソンヌ川の、合流地点となっている。'),
#  ('VOICEACTRESS100_038',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_038.wav',
#   '同時に、福井ミラクルエレファンツに、コーチ兼任で、入団することが発表された。'),
#  ('VOICEACTRESS100_039',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_039.wav',
#   '夫である小室が、救急車を呼び、都内病院に、緊急搬送される。'),
#  ('VOICEACTRESS100_040',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_040.wav',
#   'ギレスピーは、マッギーを通じて、イネスと知り合った。'),
#  ('VOICEACTRESS100_041',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_041.wav',
#   'フォンテーヌブロー様式では、寓意的な絵が、漆喰のモールドに使われている。'),
#  ('VOICEACTRESS100_042',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_042.wav',
#   '祭神は、ヴィシュヌ派の聖人、スワーミーナーラーヤン。'),
#  ('VOICEACTRESS100_043',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_043.wav',
#   'ハーデースが、ペルセポネーに恋をしたのは、アプロディーテーの、策略であるとされている。'),
#  ('VOICEACTRESS100_044',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_044.wav',
#   'クウェーンバーンチャーンは、小さなコミュニティーで、農業や、商業を中心に、成り立っていたと、考えられている。'),
#  ('VOICEACTRESS100_045',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_045.wav',
#   'ヴェーザー自転車道や、ミューレンルートに従った、サイクリングツアーは、ペータースハーゲンを、経由する。'),
#  ('VOICEACTRESS100_046',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_046.wav',
#   'フォーミュラカーは、通常、オープンホイールで、シングルシーターである。'),
#  ('VOICEACTRESS100_047',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_047.wav',
#   '同日朝に、大阪難波で、出発セレモニーが開催され、営業運転に、充当された。'),
#  ('VOICEACTRESS100_048',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_048.wav',
#   'そして、インデペンデント紙の、読者投票で選ぶ、プレミアリーグ最優秀ゴールキーパーに選ばれた。'),
#  ('VOICEACTRESS100_049',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_049.wav',
#   'プレイヤーキャラクターは、宮殿を占拠した、邪悪なクリーチャーに遭遇する。'),
#  ('VOICEACTRESS100_050',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_050.wav',
#   'フィールドマーケティングは、歴史的には、一方通行のコミュニケーションツールとして、考えられてきた。'),
#  ('VOICEACTRESS100_051',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_051.wav',
#   'デビュー後の数年間は、ベビーフェイスとして、本名で活動。'),
#  ('VOICEACTRESS100_052',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_052.wav',
#   '学校や病院などの、給食業務で、栄養素を計算する上で、重要な資料のひとつである。'),
#  ('VOICEACTRESS100_053',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_053.wav',
#   '当時、あやしいワールドに常駐していた擬古猫が、空白にて発表。'),
#  ('VOICEACTRESS100_054',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_054.wav',
#   '裕福なニューヨーカー達は、グレーヴセンド、競馬場や、シープシェッドベイ、競馬場などに集い、海沿いの高級レストランや、ホテルを利用した。'),
#  ('VOICEACTRESS100_055',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_055.wav',
#   'ウォリアーズミックスマーシャルアーツアカデミー所属。'),
#  ('VOICEACTRESS100_056',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_056.wav',
#   'ところが、エリュシクトーンは、ニュムペーの制止も聞かずに、デーメーテールの樫を、切り倒した。'),
#  ('VOICEACTRESS100_057',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_057.wav',
#   'このジェシー役でステイモスは、エミー賞にノミネートされたこともある。'),
#  ('VOICEACTRESS100_058',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_058.wav',
#   'スウェーデン移民の両親の許に、マサチューセッツ州、ケンブリッジにて生まれる。'),
#  ('VOICEACTRESS100_059',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_059.wav',
#   '球宴のファン投票でも、人気が偶像化していた、長嶋茂雄に肉薄する。'),
#  ('VOICEACTRESS100_060',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_060.wav',
#   '母は、ピーターマリッツバーグの精神病院に入院しているときに、ベッシーを産む。'),
#  ('VOICEACTRESS100_061',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_061.wav',
#   'ポイントガードから、スモールフォワードまでこなせる、総合力が高いユーティリティープレーヤーである。'),
#  ('VOICEACTRESS100_062',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_062.wav',
#   'グレッグは、ミシシッピ州、アバディーンにある、オッドフェローズ墓地に埋葬されることになった。'),
#  ('VOICEACTRESS100_063',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_063.wav',
#   '大当り終了後は、グラディエーターチャンスに突入する。'),
#  ('VOICEACTRESS100_064',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_064.wav',
#   'この菌による病気は、灰色かび病と名づけられているものが多い。'),
#  ('VOICEACTRESS100_065',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_065.wav',
#   'レギュラーメンバーの顔写真をクリックした後に、ムービープレイヤー風に再生されるという、特異な形式となっている。'),
#  ('VOICEACTRESS100_066',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_066.wav',
#   '肝臓への酸素供給は、肝動脈と、低圧系の門脈を介して、行われている。'),
#  ('VOICEACTRESS100_067',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_067.wav',
#   'デッドキーは、タイプライターや、コンピュータのキーボードにおける、特殊な装飾キーである。'),
#  ('VOICEACTRESS100_068',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_068.wav',
#   'シャンシャン馬は、鵜戸神宮へ参拝する、新婚夫婦が乗っていた馬のこと。'),
#  ('VOICEACTRESS100_069',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_069.wav',
#   'ブルーリッジ山脈の源流から、リッチモンドまで、多くの早瀬や淵が、釣りや急流くだりを楽しませてくれる。'),
#  ('VOICEACTRESS100_070',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_070.wav',
#   'ボーハンは、イーストマンら、ギャングのスピークイージーの上がりから、賄賂を取っていたとも噂された。'),
#  ('VOICEACTRESS100_071',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_071.wav',
#   'ペンシルベニア州、フィラデルフィアの郊外、ウィンレッドのレンキナウ病院で生まれた。'),
#  ('VOICEACTRESS100_072',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_072.wav',
#   'ブラッグは、ビューエル軍よりも、劣勢だったために、この機会を生かすことを躊躇した。'),
#  ('VOICEACTRESS100_073',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_073.wav',
#   '上院議員として、バーンウェルは、カリフォルニア州の、連邦加入に賛成した。'),
#  ('VOICEACTRESS100_074',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_074.wav',
#   'レジェンドシリーズをベースに、ヨーフリー機構を備えた、ビューカメラ。'),
#  ('VOICEACTRESS100_075',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_075.wav',
#   '楽曲のセンターポジションは、エーケービーフォーティーエイトの、高橋みなみが務めた。'),
#  ('VOICEACTRESS100_076',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_076.wav',
#   'ディオニューソスの、寵愛を受ける、オイネウス王と、妃、アルタイアーの間に、カリュドーンの王女として、生を受けた。'),
#  ('VOICEACTRESS100_077',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_077.wav',
#   '大西洋上の、巡航高度から、動力なしで、地上へ滑空飛行し、緊急着陸に成功した。'),
#  ('VOICEACTRESS100_078',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_078.wav',
#   '表現行列の指標表を、分子の対称性を表す、点群の指標表を用いて、既約表現へ分解する。'),
#  ('VOICEACTRESS100_079',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_079.wav',
#   '大洋漁業オーナーの、中部謙吉の命を受けて、プロ野球球団の、大洋ホエールズに関わる。'),
#  ('VOICEACTRESS100_080',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_080.wav',
#   'かすかに聞こえてくる1931年版の讃美歌が、次第に大きくなっていく。'),
#  ('VOICEACTRESS100_081',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_081.wav',
#   'モーイーデーン岩壁地域の上部は、プラーサートプラウィハーン寺院遺跡へ繋がる、タイ側参道に続いている。'),
#  ('VOICEACTRESS100_082',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_082.wav',
#   'カーミラ星と呼ばれている惑星から、宇宙船に乗って、地球に侵入した宇宙人。'),
#  ('VOICEACTRESS100_083',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_083.wav',
#   'ドッガーバンクは、タラやニシンの漁獲量が多い、重要な、漁場である。'),
#  ('VOICEACTRESS100_084',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_084.wav',
#   '少年時代は、ロシア帝国、チェルニーヒウ県、プルィルークィ郡、トロスチャヌィーツャ村で過ごした。'),
#  ('VOICEACTRESS100_085',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_085.wav',
#   '遺灰のほとんどは、スウェーデン西海岸の、ブーヒュースレーン地方の小島にある漁村、フヤルバッカ周辺の海に、散骨された。'),
#  ('VOICEACTRESS100_086',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_086.wav',
#   '国境を越えて、列車は、改良された在来線に沿って、アーヘン中央駅に向かう。'),
#  ('VOICEACTRESS100_087',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_087.wav',
#   '福岡ダイエーホークスではなく、長距離砲の補強を目指していた、大阪近鉄バファローズから、オファーを受けて入団。'),
#  ('VOICEACTRESS100_088',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_088.wav',
#   'そこには、百ドル札と、アメリカに来いという、短いメッセージだけだった。'),
#  ('VOICEACTRESS100_089',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_089.wav',
#   '現在は、バッハをモチーフとした、ハープシコードの作曲家として、記憶されている。'),
#  ('VOICEACTRESS100_090',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_090.wav',
#   '戦闘服は、両腕を露出し、両脚が、アンダースーツで覆われている。'),
#  ('VOICEACTRESS100_091',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_091.wav',
#   '同母姉に、スウェーデン王妃、ジョゼフィーヌがいる。'),
#  ('VOICEACTRESS100_092',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_092.wav',
#   '紫外線は、表面エネルギーの、小さいポリマーを接着する際の、前処理に利用される。'),
#  ('VOICEACTRESS100_093',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_093.wav',
#   '自身のページで、メッセージや、公開コメントを通して、レビューを投稿したユーザーと、コミュニケーションを取ることが可能である。'),
#  ('VOICEACTRESS100_094',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_094.wav',
#   '若き日の反逆ゆえに、宇宙の中央を追放されて、惑星、地球にやってきた主人公、ベルゼバブが、宇宙船カルナークのなかで、孫に語る壮大な物語。'),
#  ('VOICEACTRESS100_095',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_095.wav',
#   'ジャガーとは対照的に、ボディービルダーを髣髴とさせる、マッチョな体育会系の外見が特徴。'),
#  ('VOICEACTRESS100_096',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_096.wav',
#   'ペンシルベニア州、ピッツバーグの、アレゲーニー高校を卒業し、カリフォルニア大学、バークレー校に入学。'),
#  ('VOICEACTRESS100_097',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_097.wav',
#   'この概念の導入によって、様々なバリエーションの、流体のコンピューターシミュレーションが、高い精度で可能となった。'),
#  ('VOICEACTRESS100_098',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_098.wav',
#   '乾ドックに入渠して、オーバーホールすべきかどうか、パフォーマンスがチェックされた。'),
#  ('VOICEACTRESS100_099',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_099.wav',
#   'デビューウェイトは、スーパーバンタム級ではなく、フェザー級だった。'),
#  ('VOICEACTRESS100_100',
#   'jvs/jvs_ver1/jvs024/parallel100/wav24kHz16bit/VOICEACTRESS100_100.wav',
#   'アーリーは、降雨の中を、南のバージニア州、ウィンチェスター近くの、フィッシャーズヒルまで、軍を退いた。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('BASIC5000_1024',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/BASIC5000_1024.wav',
#   '昨今、個人的自由は少なくなっている。'),
#  ('BASIC5000_0193',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/BASIC5000_0193.wav',
#   'ご家族もごいっしょに連れてこられたのですか。'),
#  ('TRAVEL1000_0286',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/TRAVEL1000_0286.wav',
#   '飛行機はサービスがよく、可能な限り、客の要望に答えられるように努力しています。'),
#  ('TRAVEL1000_0594',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/TRAVEL1000_0594.wav',
#   'このセーターの色違いのがありますか。'),
#  ('BASIC5000_0394',
#   'jvs/jvs_ver1/jvs024/falset10/wav24kHz16bit/BASIC5000_0394.wav',
#   'パシフィック通りに行くには、このバスでいいんでしょうか。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('TRAVEL1000_0655',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/TRAVEL1000_0655.wav',
#   '運転手付きのリムジンは、40ドルです。'),
#  ('BASIC5000_0086',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/BASIC5000_0086.wav',
#   '占星学は科学的な根拠もないのに、とても人気があって、占星学は信じている人が多いようです。'),
#  ('UT-PARAPHRASE-sent303-phrase2',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/UT-PARAPHRASE-sent303-phrase2.wav',
#   '歴史と現代、都市と自然が交錯する、異様な場所。'),
#  ('BASIC5000_0412',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/BASIC5000_0412.wav',
#   '九月で彼女と知り合って、まる一年経つことになる。'),
#  ('TRAVEL1000_0800',
#   'jvs/jvs_ver1/jvs083/whisper10/wav24kHz16bit/TRAVEL1000_0800.wav',
#   '今日、課せられたペーパーが、よく分かりませんでした。'),
#  ('TRAVEL1000_0655',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0655.wav',
#   '運転手付きのリムジンは、40ドルです。'),
#  ('BASIC5000_0086',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_0086.wav',
#   '占星学は科学的な根拠もないのに、とても人気があって、占星学は信じている人が多いようです。'),
#  ('UT-PARAPHRASE-sent303-phrase2',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent303-phrase2.wav',
#   '歴史と現代、都市と自然が交錯する、異様な場所。'),
#  ('BASIC5000_0412',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_0412.wav',
#   '九月で彼女と知り合って、まる一年経つことになる。'),
#  ('TRAVEL1000_0800',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0800.wav',
#   '今日、課せられたペーパーが、よく分かりませんでした。'),
#  ('TRAVEL1000_0213',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0213.wav',
#   '薬が効かなければ、どうしましょうか。'),
#  ('TRAVEL1000_0817',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0817.wav',
#   'サンフランシスコには、何時に着きますか。'),
#  ('TRAVEL1000_0804',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0804.wav',
#   '2時10分の飛行機をお願いします。'),
#  ('TRAVEL1000_0912',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0912.wav',
#   '歯医者に見ていただく必要がありますか。'),
#  ('TRAVEL1000_0273',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0273.wav',
#   'それにクレジットカード、保険証と、運転免許証も入っていました。'),
#  ('BASIC5000_0850',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_0850.wav',
#   '出水の被害は、１０００万ドルに達している。'),
#  ('UT-PARAPHRASE-sent237-phrase2',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent237-phrase2.wav',
#   '心臓のような形の葉は鉢に、エイのヒレがうねる様子は、皿になった。'),
#  ('BASIC5000_2168',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_2168.wav',
#   '当面は、彼に調子を合わせておいたほうがいいぞ。'),
#  ('TRAVEL1000_0605',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0605.wav',
#   '教えていただいた人に、お礼を述べるのも忘れないようにしてください。'),
#  ('LOANWORD128_067',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/LOANWORD128_067.wav',
#   'グィネヴィアは小惑星帯の外縁部付近に位置する小惑星である。'),
#  ('TRAVEL1000_0186',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0186.wav',
#   '両方で、4ドル90セントです。'),
#  ('BASIC5000_2066',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_2066.wav',
#   'うん、私はただ、のんびり過ごすつもりよ。'),
#  ('BASIC5000_2040',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_2040.wav',
#   '階層問題に対する、消費社会論の著である。'),
#  ('BASIC5000_0698',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_0698.wav',
#   '反対申し上げるつもりは、全然なかったのです。'),
#  ('BASIC5000_0161',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_0161.wav',
#   '銃を掃除していたら、突然暴発してしまった。'),
#  ('UT-PARAPHRASE-sent069-phrase1',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent069-phrase1.wav',
#   '夏への課題は、目に見えないエラーをなくすことです。'),
#  ('ONOMATOPEE300_214',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/ONOMATOPEE300_214.wav',
#   '彼女はガップリよつの横綱相撲に見入った。'),
#  ('UT-PARAPHRASE-sent064-phrase2',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent064-phrase2.wav',
#   'うねるような豊かな金髪に、ブラシをかけている女性の姿は、印象派の画家が、よく描いている。'),
#  ('ONOMATOPEE300_010',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/ONOMATOPEE300_010.wav',
#   '何が楽しいのか、甥っ子が、ゴミ箱の蓋をカパカパ開け閉めして遊んでいる。'),
#  ('LOANWORD128_046',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/LOANWORD128_046.wav',
#   '大学の授業で、私は先生の難しい講義をメモる。'),
#  ('UT-PARAPHRASE-sent187-phrase1',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent187-phrase1.wav',
#   '政令市になれば県を通さず、霞が関とじかに折衝する機会が増える。'),
#  ('BASIC5000_2149',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_2149.wav',
#   'ナチズムは、ドイツ独特のものでしたか。'),
#  ('TRAVEL1000_0832',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/TRAVEL1000_0832.wav',
#   '約、3ー4週間で、1ー20の3、4頁とＩー94を受け取ります。'),
#  ('BASIC5000_1682',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_1682.wav',
#   '駅に行く道を、お教えいたしましょう。'),
#  ('BASIC5000_0577',
#   'jvs/jvs_ver1/jvs083/nonpara30/wav24kHz16bit/BASIC5000_0577.wav',
#   '顧客に対する勧誘の電話が、テレマーケティング部の主要業務である。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs083/parallel100/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs083/parallel100/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs083/parallel100/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
# ...
#   'jvs/jvs_ver1/jvs068/parallel100/wav24kHz16bit/VOICEACTRESS100_096.wav',
#   'ペンシルベニア州、ピッツバーグの、アレゲーニー高校を卒業し、カリフォルニア大学、バークレー校に入学。'),
#  ('VOICEACTRESS100_097',
#   'jvs/jvs_ver1/jvs068/parallel100/wav24kHz16bit/VOICEACTRESS100_097.wav',
#   'この概念の導入によって、様々なバリエーションの、流体のコンピューターシミュレーションが、高い精度で可能となった。'),
#  ('VOICEACTRESS100_098',
#   'jvs/jvs_ver1/jvs068/parallel100/wav24kHz16bit/VOICEACTRESS100_098.wav',
#   '乾ドックに入渠して、オーバーホールすべきかどうか、パフォーマンスがチェックされた。'),
#  ('VOICEACTRESS100_099',
#   'jvs/jvs_ver1/jvs068/parallel100/wav24kHz16bit/VOICEACTRESS100_099.wav',
#   'デビューウェイトは、スーパーバンタム級ではなく、フェザー級だった。'),
#  ('VOICEACTRESS100_100',
#   'jvs/jvs_ver1/jvs068/parallel100/wav24kHz16bit/VOICEACTRESS100_100.wav',
#   'アーリーは、降雨の中を、南のバージニア州、ウィンチェスター近くの、フィッシャーズヒルまで、軍を退いた。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('TRAVEL1000_0146',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/TRAVEL1000_0146.wav',
#   'タクシーや、貸切りのリムジンなどは、よく料金を確かめてから利用しましょう。'),
#  ('BASIC5000_0735',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/BASIC5000_0735.wav',
#   '五郎は、親切にも私を病院へ連れて行ってくれた。'),
#  ('TRAVEL1000_0522',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/TRAVEL1000_0522.wav',
#   'オープンマーケットは、どちらの方向ですか。'),
#  ('BASIC5000_1759',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/BASIC5000_1759.wav',
#   '彼きっと、その企てに成功するだろう。'),
#  ('UT-PARAPHRASE-sent123-phrase1',
#   'jvs/jvs_ver1/jvs068/falset10/wav24kHz16bit/UT-PARAPHRASE-sent123-phrase1.wav',
#   '暗く、重々しいファンファーレが、ホールの空気を、鋭く切り裂く。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('ONOMATOPEE300_097',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/ONOMATOPEE300_097.wav',
#   'ホテルから出てきたカップルは、妙にテカテカしている。'),
#  ('BASIC5000_0897',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/BASIC5000_0897.wav',
#   '使者は、ひそかにロンドンへ出発した。'),
#  ('UT-PARAPHRASE-sent014-phrase1',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/UT-PARAPHRASE-sent014-phrase1.wav',
#   'だから返答には、明細な意図の説明を期待している。'),
#  ('BASIC5000_2753',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/BASIC5000_2753.wav',
#   '測定には、寸分の狂いもない精度が要求される。'),
#  ('BASIC5000_0098',
#   'jvs/jvs_ver1/jvs033/whisper10/wav24kHz16bit/BASIC5000_0098.wav',
#   '全てを捨てて、このレストランをやる目的は、ひとつだけでした。'),
#  ('ONOMATOPEE300_097',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/ONOMATOPEE300_097.wav',
#   'ホテルから出てきたカップルは、妙にテカテカしている。'),
#  ('BASIC5000_0897',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0897.wav',
#   '使者は、ひそかにロンドンへ出発した。'),
#  ('UT-PARAPHRASE-sent014-phrase1',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent014-phrase1.wav',
#   'だから返答には、明細な意図の説明を期待している。'),
#  ('BASIC5000_2753',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_2753.wav',
#   '測定には、寸分の狂いもない精度が要求される。'),
#  ('BASIC5000_0098',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0098.wav',
#   '全てを捨てて、このレストランをやる目的は、ひとつだけでした。'),
#  ('BASIC5000_1191',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_1191.wav',
#   '村の人たちが、自然環境に関して話した議論は白熱した。'),
#  ('BASIC5000_0266',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0266.wav',
#   '短い手紙でもいいから、きっと書いてね。'),
#  ('BASIC5000_0786',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0786.wav',
#   '言えというなら言いますが、漫画を読むのはまったく時間の無駄である。'),
#  ('ONOMATOPEE300_203',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/ONOMATOPEE300_203.wav',
#   'うなぎの見た目は、ニュルニュルしていてあまり好きじゃない。'),
#  ('TRAVEL1000_0199',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/TRAVEL1000_0199.wav',
#   '1をダイアルして、受信音がしたら、市外局番と、電話番号をダイアルしてください。'),
#  ('TRAVEL1000_0161',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/TRAVEL1000_0161.wav',
#   '電話してくださってありがとう。'),
#  ('LOANWORD128_100',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/LOANWORD128_100.wav',
#   'フィリピンは、東南アジアに位置する共和制国家である。'),
#  ('BASIC5000_0936',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0936.wav',
#   '一介の学生にすぎないので、私は結婚する余裕がない。'),
#  ('BASIC5000_2302',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_2302.wav',
#   '誕生日には、新しい自転車をあげよう。'),
#  ('BASIC5000_2002',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_2002.wav',
#   'キャロルは、レンタカーを運転しています。'),
#  ('BASIC5000_0508',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0508.wav',
#   'お腹が空いていたばかりでなく、私達は、喉の渇きにも苦しんでいた。'),
#  ('UT-PARAPHRASE-sent305-phrase2',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent305-phrase2.wav',
#   '総会を控え、ニッポン放送も、ブルドックも、警戒する。'),
#  ('BASIC5000_0500',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0500.wav',
#   '５人に１人が、車を持つような日も、遠くあるまい。'),
#  ('BASIC5000_3085',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_3085.wav',
#   '生まれた時の臍の緒の切り方が、臍ヘルニアの原因であると言われているが、これは俗説である。'),
#  ('BASIC5000_2042',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_2042.wav',
#   '駅前の人込みの中で、私は誰かが私の名前を呼ぶのを聞いた。'),
#  ('UT-PARAPHRASE-sent059-phrase2',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent059-phrase2.wav',
#   '個々の力が集まる五輪の舞台。'),
#  ('BASIC5000_1664',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_1664.wav',
#   '三島由紀夫は、１９７０年に自殺した。'),
#  ('BASIC5000_0594',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0594.wav',
#   'ページの下の合計額は、繰り越しになっている。'),
#  ('UT-PARAPHRASE-sent019-phrase1',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent019-phrase1.wav',
#   'よもや、同じ運命をたどることはあるまいが。'),
#  ('BASIC5000_0167',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0167.wav',
#   'バクスゲン社の研究所で、新薬の試験が行われた。'),
#  ('UT-PARAPHRASE-sent093-phrase1',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/UT-PARAPHRASE-sent093-phrase1.wav',
#   '特定の遺伝子の断片を、短時間で大量に複製する技術。'),
#  ('BASIC5000_1819',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_1819.wav',
#   '祖父は、よく新聞を読みながら、こっくりこっくりする。'),
#  ('ONOMATOPEE300_035',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/ONOMATOPEE300_035.wav',
#   'そんなにバットをブンブン振り回したら、ボールになかなか当たらないので、もっとコンパクトに振る。'),
#  ('BASIC5000_3050',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_3050.wav',
#   '葉や茎の汁は、フラノクマリンを含むため、光線過敏を引き起こす。'),
#  ('BASIC5000_0432',
#   'jvs/jvs_ver1/jvs033/nonpara30/wav24kHz16bit/BASIC5000_0432.wav',
#   'まちがって、あなたの手紙を開けてしまってすみません。'),
#  ('VOICEACTRESS100_001',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_001.wav',
#   'また、東寺のように、五大明王と呼ばれる、主要な明王の中央に配されることも多い。'),
#  ('VOICEACTRESS100_002',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_002.wav',
#   'ニューイングランド風は、牛乳をベースとした、白いクリームスープであり、ボストンクラムチャウダーとも呼ばれる。'),
#  ('VOICEACTRESS100_003',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_003.wav',
#   'コンピュータゲームのメーカーや、業界団体などに関連する人物のカテゴリ。'),
#  ('VOICEACTRESS100_004',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_004.wav',
#   'サービスマネージャー導入駅のため、大井町駅から、遠隔管理している。'),
#  ('VOICEACTRESS100_005',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_005.wav',
#   'シルバーサーファー襲撃事件までに、リチャーズは、チーム名と共に、国際的にスーパーヒーロー、および、有名人として、認知されている。'),
#  ('VOICEACTRESS100_006',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_006.wav',
#   'ツュレンハルト領は、ヴュルテンベルク領に編入された。'),
#  ('VOICEACTRESS100_007',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_007.wav',
#   '時間領域と、空間領域で共通する処理手法は、フィルタリングによる、入力信号の強化である。'),
#  ('VOICEACTRESS100_008',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_008.wav',
#   'シャンチーの専業プロは、チームから支払われる給料と、対局費を、主な収入としている。'),
#  ('VOICEACTRESS100_009',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_009.wav',
#   'また禰寝氏は、中山王の治める、琉球王国との交易にも参加した。'),
#  ('VOICEACTRESS100_010',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_010.wav',
#   'スマートフォンから、フィーチャーフォンまで、マルチデバイスに対応。'),
#  ('VOICEACTRESS100_011',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_011.wav',
#   '軽妙洒脱なナレーションから、情緒感溢れる語りまで、幅広い表現力を持つ。'),
#  ('VOICEACTRESS100_012',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_012.wav',
#   '構造は、鋼製の単一アーチで、橋脚は、石積みである。'),
#  ('VOICEACTRESS100_013',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_013.wav',
#   'そこへ、オーナーが新しいシェフとして、腕利きのヒョヌクを招く。'),
#  ('VOICEACTRESS100_014',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_014.wav',
#   'クィーンズアベニューアルファに所属している。'),
#  ('VOICEACTRESS100_015',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_015.wav',
#   '一方で、漁業と商業で、リャネス港は繁栄していた。'),
#  ('VOICEACTRESS100_016',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_016.wav',
#   'この、ニューサウスウェールズ代表チームが、ワラビーズの中核となって行く。'),
#  ('VOICEACTRESS100_017',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_017.wav',
#   'ただし、ギャンブル依存症の入院治療を行っている病院は、わずかである。'),
#  ('VOICEACTRESS100_018',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_018.wav',
#   '他のメジャーなディストリビューションに比べ、セキュリティー上の問題の修正が、遅い場合もある。'),
#  ('VOICEACTRESS100_019',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_019.wav',
#   'ベルガートーア前の、ヴェディゲンウーファーパークには、戦争と弾圧の犠牲者のための記念碑が建っている。'),
#  ('VOICEACTRESS100_020',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_020.wav',
#   '全米パブリッシャーズ協会の、ベストストラテジーゲームオブザイヤーを、日本人として受賞。'),
#  ('VOICEACTRESS100_021',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_021.wav',
#   '痛みは、点滴より鎮痛薬を、静脈投与することで、鎮痛を行う。'),
#  ('VOICEACTRESS100_022',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_022.wav',
#   'このときに、浮遊大陸プルヴァマにある、中立国、ビュエルバが、ある情報筋から、バッシュ将軍の処刑と、前王女、アーシェの自害を発表。'),
#  ('VOICEACTRESS100_023',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_023.wav',
#   '南西部ウォーレンは、ベイアーマンファームズと、フィッツジェラルドの地区で、構成される。'),
#  ('VOICEACTRESS100_024',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_024.wav',
#   'このため、プラズマ中のイオンや、電子の持つ、平均運動エネルギーを、温度で表現することがある。'),
#  ('VOICEACTRESS100_025',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_025.wav',
#   'その飄々とした人柄が、老若男女に慕われている。'),
#  ('VOICEACTRESS100_026',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_026.wav',
#   '現在、ニュージャージー州、ムーアズタウンに住んでいる。'),
#  ('VOICEACTRESS100_027',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_027.wav',
#   '町域にあった、三根山藩は、長岡藩に、米百俵を送ったことで有名。'),
#  ('VOICEACTRESS100_028',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_028.wav',
#   'このとき、ペリメーデーは、アムピクトリュオーンに同行して、テーバイに来ていた、リキュムニオスに、妻としてあたえられた。'),
#  ('VOICEACTRESS100_029',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_029.wav',
#   '現在の滑走を目的とした、スキーブーツは、硬いプラスチックシェルと、柔らかいインナーブーツからなる。'),
#  ('VOICEACTRESS100_030',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_030.wav',
#   '防氷ブーツは、表面に張られた、ゴム製の薄い膜でできている。'),
#  ('VOICEACTRESS100_031',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_031.wav',
#   '後者の代表が、ウェッジウッドの、ジャスパーウェアである。'),
#  ('VOICEACTRESS100_032',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_032.wav',
#   'キー局が発信する、ニュースネットワーク名を冠したタイトルの、ニュース番組の中では、レギュラー放送が、最も多い。'),
#  ('VOICEACTRESS100_033',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_033.wav',
#   '芸能プロダクション、アミューズのグループ企業。'),
#  ('VOICEACTRESS100_034',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_034.wav',
#   '長母音を省略して、エリュシオンとも表記される。'),
#  ('VOICEACTRESS100_035',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_035.wav',
#   '森永のおいしい牛乳は、濃い青色に、牛乳瓶をあしらったデザインの、パック牛乳である。'),
#  ('VOICEACTRESS100_036',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_036.wav',
#   '番組冒頭を、東京ムービー製作のアニメーションで、表現する点も、共通していた。'),
#  ('VOICEACTRESS100_037',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_037.wav',
#   'コミューンは、セーヌ川と、エソンヌ川の、合流地点となっている。'),
#  ('VOICEACTRESS100_038',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_038.wav',
#   '同時に、福井ミラクルエレファンツに、コーチ兼任で、入団することが発表された。'),
#  ('VOICEACTRESS100_039',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_039.wav',
#   '夫である小室が、救急車を呼び、都内病院に、緊急搬送される。'),
#  ('VOICEACTRESS100_040',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_040.wav',
#   'ギレスピーは、マッギーを通じて、イネスと知り合った。'),
#  ('VOICEACTRESS100_041',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_041.wav',
#   'フォンテーヌブロー様式では、寓意的な絵が、漆喰のモールドに使われている。'),
#  ('VOICEACTRESS100_042',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_042.wav',
#   '祭神は、ヴィシュヌ派の聖人、スワーミーナーラーヤン。'),
#  ('VOICEACTRESS100_043',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_043.wav',
#   'ハーデースが、ペルセポネーに恋をしたのは、アプロディーテーの、策略であるとされている。'),
#  ('VOICEACTRESS100_044',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_044.wav',
#   'クウェーンバーンチャーンは、小さなコミュニティーで、農業や、商業を中心に、成り立っていたと、考えられている。'),
#  ('VOICEACTRESS100_045',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_045.wav',
#   'ヴェーザー自転車道や、ミューレンルートに従った、サイクリングツアーは、ペータースハーゲンを、経由する。'),
#  ('VOICEACTRESS100_046',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_046.wav',
#   'フォーミュラカーは、通常、オープンホイールで、シングルシーターである。'),
#  ('VOICEACTRESS100_047',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_047.wav',
#   '同日朝に、大阪難波で、出発セレモニーが開催され、営業運転に、充当された。'),
#  ('VOICEACTRESS100_048',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_048.wav',
#   'そして、インデペンデント紙の、読者投票で選ぶ、プレミアリーグ最優秀ゴールキーパーに選ばれた。'),
#  ('VOICEACTRESS100_049',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_049.wav',
#   'プレイヤーキャラクターは、宮殿を占拠した、邪悪なクリーチャーに遭遇する。'),
#  ('VOICEACTRESS100_050',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_050.wav',
#   'フィールドマーケティングは、歴史的には、一方通行のコミュニケーションツールとして、考えられてきた。'),
#  ('VOICEACTRESS100_051',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_051.wav',
#   'デビュー後の数年間は、ベビーフェイスとして、本名で活動。'),
#  ('VOICEACTRESS100_052',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_052.wav',
#   '学校や病院などの、給食業務で、栄養素を計算する上で、重要な資料のひとつである。'),
#  ('VOICEACTRESS100_053',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_053.wav',
#   '当時、あやしいワールドに常駐していた擬古猫が、空白にて発表。'),
#  ('VOICEACTRESS100_054',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_054.wav',
#   '裕福なニューヨーカー達は、グレーヴセンド、競馬場や、シープシェッドベイ、競馬場などに集い、海沿いの高級レストランや、ホテルを利用した。'),
#  ('VOICEACTRESS100_055',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_055.wav',
#   'ウォリアーズミックスマーシャルアーツアカデミー所属。'),
#  ('VOICEACTRESS100_056',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_056.wav',
#   'ところが、エリュシクトーンは、ニュムペーの制止も聞かずに、デーメーテールの樫を、切り倒した。'),
#  ('VOICEACTRESS100_057',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_057.wav',
#   'このジェシー役でステイモスは、エミー賞にノミネートされたこともある。'),
#  ('VOICEACTRESS100_058',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_058.wav',
#   'スウェーデン移民の両親の許に、マサチューセッツ州、ケンブリッジにて生まれる。'),
#  ('VOICEACTRESS100_059',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_059.wav',
#   '球宴のファン投票でも、人気が偶像化していた、長嶋茂雄に肉薄する。'),
#  ('VOICEACTRESS100_060',
#   'jvs/jvs_ver1/jvs033/parallel100/wav24kHz16bit/VOICEACTRESS100_060.wav',
#   '母は、ピーターマリッツバーグの精神病院に入院しているときに、ベッシーを産む。'),
#  ...]

# %%
# !pip3 install --upgrade setuptools
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: setuptools in /home/lu/pythonEnvs/FinetuneWhisper/lib/python3.10/site-packages (59.6.0)
# Collecting setuptools
#   Downloading setuptools-68.1.2-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.1/805.1 KB 3.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.6.0
#     Uninstalling setuptools-59.6.0:
#       Successfully uninstalled setuptools-59.6.0
# Successfully installed setuptools-68.1.2

# %%
def text_kana_convert(text):
    text = pyopenjtalk.g2p(text, kana=True)
    return text
print(text_kana_convert("こんにちは、私の名前は、田中一郎です。"))

# %%
woptions = whisper.DecodingOptions(language="ja", without_timestamps=True)
wmodel = whisper.load_model("base")
wtokenizer = whisper.tokenizer.get_tokenizer(True, language="ja", task=woptions.task)

# %%
class JvsSpeechDataset(torch.utils.data.Dataset):
    def __init__(self, audio_info_list, tokenizer, sample_rate) -> None:
        super().__init__()

        self.audio_info_list = audio_info_list
        self.sample_rate = sample_rate
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.audio_info_list)
    
    def __getitem__(self, id):
        audio_id, audio_path, text = self.audio_info_list[id]

        # audio
        audio = load_wave(audio_path, sample_rate=self.sample_rate)
        audio = whisper.pad_or_trim(audio.flatten())
        mel = whisper.log_mel_spectrogram(audio)

        text = text_kana_convert(text)
        text = [*self.tokenizer.sot_sequence_including_notimestamps] + self.tokenizer.encode(text)
        labels = text[1:] + [self.tokenizer.eot]

        return {
            "input_ids": mel,
            "labels": labels,
            "dec_input_ids": text
        }

# %%
class WhisperDataCollatorWhithPadding:
    def __call__(sefl, features):
        input_ids, labels, dec_input_ids = [], [], []
        for f in features:
            input_ids.append(f["input_ids"])
            labels.append(f["labels"])
            dec_input_ids.append(f["dec_input_ids"])

        input_ids = torch.concat([input_id[None, :] for input_id in input_ids])
        
        label_lengths = [len(lab) for lab in labels]
        dec_input_ids_length = [len(e) for e in dec_input_ids]
        max_label_len = max(label_lengths+dec_input_ids_length)

        labels = [np.pad(lab, (0, max_label_len - lab_len), 'constant', constant_values=-100) for lab, lab_len in zip(labels, label_lengths)]
        dec_input_ids = [np.pad(e, (0, max_label_len - e_len), 'constant', constant_values=50257) for e, e_len in zip(dec_input_ids, dec_input_ids_length)] # 50257 is eot token id

        batch = {
            "labels": labels,
            "dec_input_ids": dec_input_ids
        }

        batch = {k: torch.tensor(np.array(v), requires_grad=False) for k, v in batch.items()}
        batch["input_ids"] = input_ids

        return batch

# %%
def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

# %%
dataset = JvsSpeechDataset(eval_audio_transcript_pair_list, wtokenizer, SAMPLE_RATE)
loader = torch.utils.data.DataLoader(dataset, batch_size=2, collate_fn=WhisperDataCollatorWhithPadding())

# %%
for b in loader:
    print(b["labels"].shape)
    print(b["input_ids"].shape)
    print(b["dec_input_ids"].shape)

    for token, dec in zip(b["labels"], b["dec_input_ids"]):
        token[token == -100] = wtokenizer.eot
        text = wtokenizer.decode(token, skip_special_tokens=False)
        print(text)

        dec[dec == -100] = wtokenizer.eot
        text = wtokenizer.decode(dec, skip_special_tokens=False)
        print(text)


    break

# %%
with torch.no_grad():
    audio_features = wmodel.encoder(b["input_ids"].cuda())
    input_ids = b["input_ids"]
    labels = b["labels"].long()
    dec_input_ids = b["dec_input_ids"].long()

        
    audio_features = wmodel.encoder(input_ids.cuda())
    print(dec_input_ids)
    print(input_ids.shape, dec_input_ids.shape, audio_features.shape)
    print(audio_features.shape)
    print()
out = wmodel.decoder(dec_input_ids.cuda(), audio_features)

# %%
print(out.shape)
print(out.view(-1, out.size(-1)).shape)
print(b["labels"].view(-1).shape)

# %%
tokens = torch.argmax(out, dim=2)
for token in tokens:
    token[token == -100] = wtokenizer.eot
    text = wtokenizer.decode(token, skip_special_tokens=True)
    print(text)

# %%
class Config:
    learning_rate = 0.0005
    weight_decay = 0.01
    adam_epsilon = 1e-8
    warmup_steps = 2
    batch_size = 16
    num_worker = 2
    num_train_epochs = 10
    gradient_accumulation_steps = 1
    sample_rate = SAMPLE_RATE

# %%
class WhisperModelModule(LightningModule):
    def __init__(self, cfg:Config, model_name="base", lang="ja", train_dataset=[], eval_dataset=[]) -> None:
        super().__init__()
        self.options = whisper.DecodingOptions(language=lang, without_timestamps=True)
        self.model = whisper.load_model(model_name)
        self.tokenizer = whisper.tokenizer.get_tokenizer(True, language="ja", task=self.options.task)

        # only decoder training
        for p in self.model.encoder.parameters():
            p.requires_grad = False
        
        self.loss_fn = nn.CrossEntropyLoss(ignore_index=-100)
        self.metrics_wer = evaluate.load("wer")
        self.metrics_cer = evaluate.load("cer")

        self.cfg = cfg
        self.__train_dataset = train_dataset
        self.__eval_dataset = eval_dataset
    
    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_id):
        ###Mel spectogram
        input_ids = batch["input_ids"]
        
        labels = batch["labels"].long()
        dec_input_ids = batch["dec_input_ids"].long()

        with torch.no_grad():
            audio_features = self.model.encoder(input_ids)

        out = self.model.decoder(dec_input_ids, audio_features)
        loss = self.loss_fn(out.view(-1, out.size(-1)), labels.view(-1))
        self.log("train/loss", loss, on_step=True, prog_bar=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_id):
        input_ids = batch["input_ids"]
        labels = batch["labels"].long()
        dec_input_ids = batch["dec_input_ids"].long()


        audio_features = self.model.encoder(input_ids)
        out = self.model.decoder(dec_input_ids, audio_features)

        loss = self.loss_fn(out.view(-1, out.size(-1)), labels.view(-1))

        out[out == -100] = self.tokenizer.eot
        labels[labels == -100] = self.tokenizer.eot

        o_list, l_list = [], []
        for o, l in zip(out, labels):
            o = torch.argmax(o, dim=1)
            o_list.append(self.tokenizer.decode(o, skip_special_tokens=True))
            l_list.append(self.tokenizer.decode(l, skip_special_tokens=True))
        cer = self.metrics_cer.compute(references=l_list, predictions=o_list)
        wer = self.metrics_wer.compute(references=l_list, predictions=o_list)

        self.log("val/loss", loss, on_step=True, prog_bar=True, logger=True)
        self.log("val/cer", cer, on_step=True, prog_bar=True, logger=True)
        self.log("val/wer", wer, on_step=True, prog_bar=True, logger=True)

        return {
            "cer": cer,
            "wer": wer,
            "loss": loss
        }

    def configure_optimizers(self):
        """オプティマイザーとスケジューラーを作成する"""
        model = self.model
        no_decay = ["bias", "LayerNorm.weight"]
        optimizer_grouped_parameters = [
            {
                "params": [p for n, p in model.named_parameters() 
                            if not any(nd in n for nd in no_decay)],
                "weight_decay": self.cfg.weight_decay,
            },
            {
                "params": [p for n, p in model.named_parameters() 
                            if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
            },
        ]
        optimizer = AdamW(optimizer_grouped_parameters, 
                          lr=self.cfg.learning_rate, 
                          eps=self.cfg.adam_epsilon)
        self.optimizer = optimizer

        scheduler = get_linear_schedule_with_warmup(
            optimizer, num_warmup_steps=self.cfg.warmup_steps, 
            num_training_steps=self.t_total
        )
        self.scheduler = scheduler

        return [optimizer], [{"scheduler": scheduler, "interval": "step", "frequency": 1}]
    
    def setup(self, stage=None):
        """初期設定（データセットの読み込み）"""

        if stage == 'fit' or stage is None:
            self.t_total = (
                (len(self.__train_dataset) // (self.cfg.batch_size))
                // self.cfg.gradient_accumulation_steps
                * float(self.cfg.num_train_epochs)
            )
    
    def train_dataloader(self):
        """訓練データローダーを作成する"""
        dataset = JvsSpeechDataset(self.__train_dataset, self.tokenizer, self.cfg.sample_rate)
        return torch.utils.data.DataLoader(dataset, 
                          batch_size=self.cfg.batch_size, 
                          drop_last=True, shuffle=True, num_workers=self.cfg.num_worker,
                          collate_fn=WhisperDataCollatorWhithPadding()
                          )

    def val_dataloader(self):
        """バリデーションデータローダーを作成する"""
        dataset = JvsSpeechDataset(self.__eval_dataset, self.tokenizer, self.cfg.sample_rate)
        return torch.utils.data.DataLoader(dataset, 
                          batch_size=self.cfg.batch_size, 
                          num_workers=self.cfg.num_worker,
                          collate_fn=WhisperDataCollatorWhithPadding()
                          )

# %%
state_dict = torch.load(checkpoint_path)
print(state_dict.keys())
state_dict = state_dict['state_dict']

# %%
woptions = whisper.DecodingOptions(language="ja", without_timestamps=True)
dataset = JvsSpeechDataset(eval_audio_transcript_pair_list, wtokenizer, SAMPLE_RATE)
loader = torch.utils.data.DataLoader(dataset, batch_size=2, collate_fn=WhisperDataCollatorWhithPadding())

refs = []
res = []
for b in tqdm(loader):
    input_ids = b["input_ids"].half().cuda()
    labels = b["labels"].long().cuda()
    with torch.no_grad():
        #audio_features = whisper_model.model.encoder(input_ids)
        #out = whisper_model.model.decoder(enc_input_ids, audio_features)
        results = whisper_model.model.decode(input_ids, woptions)
        for r in results:
            res.append(r.text)
        
        for l in labels:
            l[l == -100] = wtokenizer.eot
            ref = wtokenizer.decode(l, skip_special_tokens=True)
            refs.append(ref)

# %%
cer_metrics = evaluate.load("cer")
cer_metrics.compute(references=refs, predictions=res)

# %%
for k, v in zip(refs, res):
    print("-"*10)
    print(k)
    print(v)
